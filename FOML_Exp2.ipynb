# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedZaidhA/Machine-LEarning/blob/main/FOML_Exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

url = 'https://raw.githubusercontent.com/MohamedZaidhA/Machine-LEarning/refs/heads/main/Salary_dataset.csv'
df = pd.read_csv(url)

df.drop(columns=["Unnamed: 0"], inplace = True)

x="YearsExperience"
y="Salary"

display(df.head())
display(df.shape)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0
# (30, 2)

# %%
mean_Y = df[y].mean()
mean_X = df[x].mean()
variance_X = df[x].var()
covariance_matrix = df[[x, y]].cov()
covariance = covariance_matrix.loc[x, y]

b = covariance / variance_X
a = mean_Y - b * mean_X

x_values = np.linspace(0, 11, 100)
y_values = b * x_values + a



plt.figure(figsize=(10, 6))
plt.scatter(df[x], df[y], label='Data Points')
plt.plot(x_values, y_values,color="red", label=f'y = Mx + C')
plt.xlabel('Years of Exp')
plt.ylabel('Salary in Rs.')
plt.grid(True)
plt.legend()
plt.title('Simple Linear Regression using Least Square Method')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

# Calculate predicted salaries using the derived 'a' and 'b' values
df['Predicted_Y'] = a + b * df[x]

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(df[y], df['Predicted_Y'])

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.65

# %%
from sklearn.metrics import mean_squared_error


# Calculate Mean squared Error (MSE)
mse = mean_squared_error(df[y], df['Predicted_Y'])

print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 0.56

# %%
# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.75

# %%
# Calculate Relative Mean Squared Error
relativeE = mse/variance_Y
print(f"Relative Mean Squared Error (RMSE): {relativeE:.2f}")
# Out:
# Relative Mean Squared Error (RMSE): 0.49
